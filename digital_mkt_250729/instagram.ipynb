# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle # 쿠키값을 저장하거나 불러오는 것
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com/accounts/login/") # 인스타에 들어간다
print("수동으로 인증 시작!")
time.sleep(30) # 30초의 기간동안 서둘러서 아이디와 비밀번호 입력

with open("instagram_cookies.pkl", "wb") as f : # 이 이름으로 쿠키값을 받아올 것임. write binary
    pickle.dump(driver.get_cookies(), f) # 알고리즘. dump = 직렬형태로 값을 찾아와라. (직렬화되어있는 값 중에 특정 값을 찾아오는 것.)

print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동으로 인증 시작!
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com")

with open("instagram_cookies.pkl", "rb") as f : # rb -> 모드 읽어와라. 실행시켜라
    cookies = pickle.load(f)
for cookie in cookies :
    driver.add_cookie(cookie)

driver.refresh() # 새로고침
time.sleep(5)

try :
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)
except :
    pass

keyword = "여름패션"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(5)

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try :
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url": url, "caption": caption})
    except Exception as e :
        print(f"캡션 추출 실패 : {url} | 에러 : {e}") # 이미지에서 문안이 실패됐다면 어떤 것이 실패했는지
        continue
        
driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DMUnGRLPjND/
# Photo by 우쥬 | Would You on July 20, 2025. 사람 1명, 상의 및 문구: '150대요정님들' 1 50CH 요청님들 키작녀 키작녀쇼평물추천6 쇼핑몰 작녀쇼핑몰추천6 추천6 추천'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMm3PgqSw1p/
# Photo by 패션매거진 on July 27, 2025. 사람 1명 및 문구: '네 안의 숨겨진 섹시함을 꺼내줄게 귀엽기만 한 네가 이런 반전매력이 있었다고? Only Fashion OnlyFashionMagazine Magazine'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/Ct_f03xptiF/
# Photo by 크로켓 on June 27, 2023. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DL_5Qvpx8Vb/
# Photo by 하루 ㅣ closetHARU ♥ on July 11, 2025. 사람 1명, 반바지, 상의 및 문구: '핏 핏예쁜 여름 하의만 골랐.zip zip I |존장 픽 청순가련.. 예쁨 쁨가득여름하 가득 여름 하의'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DJtfhnjSK0C/
# Photo shared by Akita | 아키타 매거진 on May 16, 2025 tagging @yoonjiiii. 사람 1명 및 문구: 'Archrooffashion ATCh of fashion Akita 올여름엔 올 화이트 올화이트룩 룩'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKHCTWRSZpw/
# Photo by phaze 페이즈 on May 26, 2025. 사람 1명 이상, 머리카락, 상의 및 문구: 'phaze 민낯보다 더 시원한 여름 사복 사복.zip zip'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLeCW1gJHLl/
# Photo by 하루 ㅣ closetHARU ♥ on June 28, 2025. 사람 1명 및 문구: '@closet_haru haru 여름에도 여리한 나 필수 상의 9가지 I 여리핏 성애자 사장님이 애정하는'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLJYF-XSTDL/
# Photo by 패션매거진 on June 20, 2025. 사람 1명 및 문구: '힙녀가 되고싶은 되고 싶은 유교걸의 슬리브리스 유교걸에게 나시는 나시는"굉장한 굉장한 용기가 필요해 OnlyF.shionMagkzine Only Fashion Magazine'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMbrZ7bzzEH/
# Photo by scrollpin on July 22, 2025. 사람 1명 및 문구: 'ScrollPinA [오늘 가방 뭐 메지] 1편 "크로스백" 오늘 가방 뭐 메지 두 손이 자유로운 크로스백 추천'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMXX2-ixz9l/
# Photo shared by 러브유스 매거진 | LoveYouth mag on July 21, 2025 tagging @hippiedippy.kr. 사람 1명, 상의 및 문구: 'LAVE LAVE yχύTH 난 아무래도 편한 바지가 편한바지가좋0 좋아 편한 바지만 입는 사람 다 들어오세요!'의 이미지일 수 있음.
# ============================================================
